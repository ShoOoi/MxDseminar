# %% [markdown]
# # B3 seminar
# 1.   Yolo algorithm (Training)
# 2.   Yolo algorithm (Run)
# 3.   Open Pose (Run)
# 4.   Generative Activate Networks (Run)
# 5.   How to use Melendy Software

# %% [markdown]
# ## 1.   Generative Activation Networks (Training)

# %% [markdown]
# ### Step.1 Mount my google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Step.2 Download darknet programs

# %%
cd /content/drive/My\ Drive/Colab\ Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git clone https://github.com/taku-buntu/Killme_DCGAN.git

# %% [markdown]
# ### Step.3 Run a sample program

# %%
cd Killme_DCGAN/
# Out:
# /content/drive/My Drive/Colab Notebooks/Killme_DCGAN

# %%
# !pip install rarfile
# !python dcgan.py
# Out:
# ...
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0905 01:14:44.714009 140355181389696 deprecation_wrapper.py:119] From dcgan.py:20: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0905 01:14:44.744751 140355181389696 deprecation_wrapper.py:119] From dcgan.py:22: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0905 01:14:44.744978 140355181389696 deprecation_wrapper.py:119] From dcgan.py:22: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W0905 01:14:44.745176 140355181389696 deprecation_wrapper.py:119] From dcgan.py:23: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-09-05 01:14:44.745545: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !./darknet detector test ./cfg/coco.data ./cfg/yolov3.cfg ./yolov3.weights

# %%
import cv2
import matplotlib.pyplot as plt
import os.path

# 座標軸の削除処理
fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %% [markdown]
# ### Step.3 Train a weight file
